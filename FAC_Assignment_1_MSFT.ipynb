303600\n2012-01-30,28.969999,30.400000,28.830000,30.240000,24.568222,263158900\n2012-02-06,30.040001,30.799999,29.969999,30.500000,24.779451,212028100\n2012-02-13,30.629999,31.549999,29.850000,31.250000,25.388779,301016700\n2012-02-20,31.180000,31.680000,31.000000,31.480000,25.744011,170693200\n2012-02-27,31.240000,32.439999,31.100000,32.080002,26.234688,263780900\n2012-03-05,32.009998,32.209999,31.490000,31.990000,26.161087,202889100\n2012-03-12,31.969999,32.950001,31.820000,32.599998,26.659935,239706900\n2012-03-19,32.540001,32.610001,31.719999,32.009998,26.177443,191946300\n2012-03-26,32.189999,32.700001,31.809999,32.259998,26.381887,183165900\n2012-04-02,32.220001,32.459999,31.049999,31.520000,25.776722,178430200\n2012-04-09,31.219999,31.400000,30.230000,30.809999,25.196095,206254900\n2012-04-16,30.990000,32.889999,30.770000,32.419998,26.512733,273865400\n2012-04-23,32.310001,32.520000,31.830000,31.980000,26.152906,246492000\n2012-04-30,31.980000,32.340000,30.920000,30.980000,25.335123,206343300\n2012-05-07,30.700001,31.540001,30.100000,31.160000,25.482321,232577500\n2012-05-14,30.820000,31.040001,29.170000,29.270000,23.936701,267124700\n2012-05-21,29.100000,29.879999,28.639999,29.059999,23.920897,225546000\n2012-05-28,29.379999,29.719999,28.440001,28.450001,23.418781,175112600\n2012-06-04,28.620001,29.700001,28.320000,29.650000,24.406563,220846100\n2012-06-11,29.730000,30.080000,28.820000,30.020000,24.711134,216457700\n2012-06-18,29.990000,31.139999,29.709999,30.700001,25.270874,264217500\n2012-06-25,30.299999,30.690001,29.420000,30.590000,25. ...

# %%
data = pd.read_csv('MSFT.csv')
data
# Out:
#            Date        Open        High  ...       Close   Adj Close     Volume
# 0    2011-06-13   23.790001   24.450001  ...   24.260000   19.439810  280381700
# 1    2011-06-20   24.170000   24.860001  ...   24.299999   19.471865  309192000
# 2    2011-06-27   24.230000   26.170000  ...   26.020000   20.850117  344568900
# 3    2011-07-04   26.100000   26.980000  ...   26.920000   21.571299  196816700
# 4    2011-07-11   26.620001   27.010000  ...   26.780001   21.459116  227695600
# ..          ...         ...         ...  ...         ...         ...        ...
# 517  2021-05-10  250.869995  251.729996  ...  248.149994  247.578308  153118800
# 518  2021-05-17  246.550003  248.330002  ...  245.169998  244.605179  114541800
# 519  2021-05-24  247.789993  252.940002  ...  249.679993  249.679993   99583800
# 520  2021-05-31  251.229996  251.649994  ...  250.789993  250.789993   93202700
# 521  2021-06-07  249.979996  258.489990  ...  257.890015  257.890015  107030500
#
# [522 rows x 7 columns]

# %%
# n = len(data)
data['Date'] = pd.to_datetime(data.Date)

# %%
data['Adj Close'].plot()

# %%
X = data[['Open', 'High', 'Low', 'Volume']]
Y = data['Adj Close']

X = X.values
Y = Y.values
# print(X)
# print(Y)

# %%
Xtr,Xts,Ytr,Yts = train_test_split(X,Y)

# %%
lin_model = LinearRegression()
lin_model.fit(Xtr,Ytr)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_pred = lin_model.predict(Xts)
lin_pred
# Out:
# array([ 23.13896414,  21.95499978,  49.58160901, 147.41366662,
#        124.72914845,  26.35715991,  33.28594314,  44.16323057,
#         42.28271376, 242.53527415,  50.9050494 ,  21.57953062,
#        132.49500074,  45.10398029,  25.78878558, 125.3281307 ,
#        233.66512003,  40.43743343,  97.24446899,  43.83645464,
#        100.09741645,  69.68710624,  21.22164668,  37.34952755,
#         27.42494377,  50.98227493,  24.67626281,  33.35031941,
#         85.94763454,  35.84926266,  92.35927564, 135.53750795,
#         53.63270107,  79.94916436,  42.01861097, 133.61625451,
#        142.05237031,  80.13447643,  26.44898127,  53.99795175,
#         20.32693197,  97.30196891,  69.16674065,  53.18119922,
#         23.99667243, 208.3252508 ,  26.78401601,  50.76919157,
#        205.62754728,  32.46501413,  25.56378249,  52.57895229,
#         60.70331699, 100.96345246,  40.64726156,  68.04952797,
#         39.86543162, 169.2683289 ,  35.08360755,  35.04886089,
#         52.55087491,  20.45585566,  27.14405562,  47.45563562,
#        180.29999258, 183.7597867 , 106.21517859,  35.30889848,
#        202.38351963,  70.21009732,  24.87520738, 116.39425926,
#         22.28372409, 241.97182197,  35.2855077 , 228.54364892,
#         33.15259514, 103.01243233,  44.72664542, 116.85251097,
#        252.33718252,  27.35996713,  43.19395572,  80.07625814,
#        104.65958549, 208.0897766 , 100.1335481 ,  64.27957544,
#         49.12555766,  21.46119221, 200.97316103,  24.14727888,
#        123.75325104, 109.98395803,  41.06330324,  66.34184176,
#        106.4958066 ,  20.05912359,  42.47107486,  78.26188502,
#         60.4138395 , 119.40820824,  24.02088176,  68.29750101,
#         36.95929257,  25.60270298,  32.24469982, 129.8567244 ,
#         91.88220457,  41.48003664, 134.54039495,  69.74506867,
#         85.54640024, 212.85738414,  43.2835629 ,  27.63567418,
#         30.86304272,  46.62569053,  31.66488422, 193.86253946,
#         21.94778364,  55.1447685 ,  21.46187783, 211.96840433,
#        110.85007061,  32.5408643 ,  24.31460074, 104.36398961,
#        104.329893  ,  36.76640861,  34.38225176])

# %%
lin_compare = pd.DataFrame({'Actual':Yts, 'Predicted':lin_pred})
lin_compare
# Out:
#          Actual   Predicted
# 0     23.585363   23.138964
# 1     21.989677   21.955000
# 2     49.594524   49.581609
# 3    146.841873  147.413667
# 4    125.646935  124.729148
# ..          ...         ...
# 126   23.888794   24.314601
# 127  105.893105  104.363990
# 128  101.740143  104.329893
# 129   37.154072   36.766409
# 130   34.287125   34.382252
#
# [131 rows x 2 columns]

# %%
lin_model.score(Xts,Yts)
# Out:
# 0.9994659771364481

# %% [markdown]
# ---
#
#
# ---
#
# **Ridge Model for Microsoft(MSFT)**
#
# ---

# %%
rid_model = Ridge()
rid_model.fit(Xtr,Ytr)
rid_pred = rid_model.predict(Xts)

# %%
rid_compare = pd.DataFrame({'Actual':Yts, 'Predicted':rid_pred})
rid_compare
# Out:
#          Actual   Predicted
# 0     23.585363   23.138786
# 1     21.989677   21.954721
# 2     49.594524   49.581344
# 3    146.841873  147.414073
# 4    125.646935  124.730942
# ..          ...         ...
# 126   23.888794   24.314783
# 127  105.893105  104.366912
# 128  101.740143  104.333752
# 129   37.154072   36.765860
# 130   34.287125   34.382583
#
# [131 rows x 2 columns]

# %%
rid_model.score(Xts,Yts)
# Out:
# 0.999465883457422

# %% [markdown]
# ---
#
#
#
# ---
#
# **Elastic-Net model for Microsoft(MSFT)**
#
# ---

# %%
els_model = ElasticNet()
els_model.fit(Xtr,Ytr)
els_pred = els_model.predict(Xts)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 596.7279088713274, tolerance: 158.76477050094786
#   positive)

# %%
els_compare = pd.DataFrame({'Actual':Yts, 'Predicted':els_pred})
els_compare
# Out:
#          Actual   Predicted
# 0     23.585363   22.966403
# 1     21.989677   21.653780
# 2     49.594524   49.599024
# 3    146.841873  146.949118
# 4    125.646935  125.761267
# ..          ...         ...
# 126   23.888794   24.321728
# 127  105.893105  106.605397
# 128  101.740143  107.404012
# 129   37.154072   36.594857
# 130   34.287125   34.675111
#
# [131 rows x 2 columns]

# %%
els_model.score(Xts,Yts)
# Out:
# 0.9990978752454854

# %% [markdown]
# ---
#
#
#
# ---
#
# **Lasso model for Microsoft(MSFT)**
#
# ---

# %%
lss_model = Lasso()
lss_model.fit(Xtr,Ytr)
lss_pred = lss_model.predict(Xts)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 444.47331888371195, tolerance: 158.76477050094786
#   positive)

# %%
lss_compare = pd.DataFrame({'Actual':Yts, 'Predicted':lss_pred})
lss_compare
# Out:
#          Actual   Predicted
# 0     23.585363   22.957196
# 1     21.989677   21.630013
# 2     49.594524   49.626930
# 3    146.841873  146.838678
# 4    125.646935  125.798424
# ..          ...         ...
# 126   23.888794   24.315131
# 127  105.893105  106.758483
# 128  101.740143  107.628001
# 129   37.154072   36.611833
# 130   34.287125   34.705607
#
# [131 rows x 2 columns]

# %%
lss_model.score(Xts,Yts)
# Out:
# 0.9990552798788476

# %% [markdown]
# ---
#
#
#
# ---
# **Decision Tree Regressor model for Microsoft(MSFT)**
#
# ---

# %%
ds_model = DecisionTreeRegressor()
ds_model.fit(Xtr,Ytr)
ds_pred = ds_model.predict(Xts)

# %%
ds_compare = pd.DataFrame({'Actual':Yts, 'Predicted':ds_pred})
ds_compare
# Out:
#          Actual   Predicted
# 0     23.585363   23.333218
# 1     21.989677   22.397547
# 2     49.594524   48.893246
# 3    146.841873  149.469101
# 4    125.646935  123.921608
# ..          ...         ...
# 126   23.888794   24.711134
# 127  105.893105  109.565590
# 128  101.740143  109.565590
# 129   37.154072   36.397816
# 130   34.287125   35.035496
#
# [131 rows x 2 columns]

# %%
ds_model.score(Xts,Yts)
# Out:
# 0.9984197674846322
