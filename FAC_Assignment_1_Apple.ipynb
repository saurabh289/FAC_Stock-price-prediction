12.907756,1195401200\n2012-01-23,15.095357,16.230356,14.983929,15.974286,13.736333,2435708800\n2012-01-30,15.918214,16.428572,15.906786,16.417143,14.117149,1514466800\n2012-02-06,16.370714,17.772142,16.364286,17.622143,15.153331,2489043200\n2012-02-13,17.840357,18.796070,17.379642,17.932858,15.420515,3964091600\n2012-02-20,18.102858,18.674999,18.004286,18.657499,16.043634,2071997200\n2012-02-27,18.618214,19.578930,18.438572,19.470715,16.742926,3214962800\n2012-03-05,19.479286,19.562143,18.436428,19.470358,16.742619,3353260400\n2012-03-12,19.606428,21.428928,19.535713,20.913214,17.983339,4502187200\n2012-03-19,21.370358,21.773214,21.037500,21.287500,18.305182,3416299600\n2012-03-26,21.421070,22.194643,21.259287,21.412500,18.412664,3197608400\n2012-04-02,21.493929,22.666430,21.442142,22.631430,19.460825,2647190000\n2012-04-09,22.361786,23.000000,21.553928,21.615356,18.587103,3657858400\n2012-04-16,21.787857,22.151787,20.372143,20.463572,17.596685,4896550400\n2012-04-23,20.378929,22.071428,19.821428,21.535713,18.518621,3891246800\n2012-04-30,21.350000,21.371429,20.184643,20.187500,17.359289,2465075200\n2012-05-07,20.053572,20.567142,19.954643,20.239643,17.404127,2170820400\n2012-05-14,20.091785,20.268213,18.649286,18.942142,16.288403,2839370800\n2012-05-21,19.089287,20.589287,19.073214,20.081785,17.268381,2735611200\n2012-05-28,20.389286,20.767857,20.018572,20.035357,17.228460,1922600400\n2012-06-04,20.053572,20.735001,19.589287,20.725714,17.822104,2073948800\n2012-06-11,20.990000,21.017857,20.239286,20.504642,17.631996,2001053600\n2012-06-18,20.391430,21.071428,20.370358,20.789286,17.876766,1771582400\n20 ...

# %%
data = pd.read_csv('AAPL.csv')
data
# Out:
#            Date        Open        High  ...       Close   Adj Close      Volume
# 0    2011-06-13   11.685714   11.901786  ...   11.437857    9.835445  2188849600
# 1    2011-06-20   11.334286   11.898214  ...   11.655357   10.022475  2524177600
# 2    2011-06-27   11.699643   12.267857  ...   12.259286   10.541796  1744926400
# 3    2011-07-04   12.250000   12.857143  ...   12.846786   11.046986  1688976800
# 4    2011-07-11   12.726429   13.035714  ...   13.032857   11.206989  2200923200
# ..          ...         ...         ...  ...         ...         ...         ...
# 517  2021-05-10  129.410004  129.539993  ...  127.449997  127.449997   514054100
# 518  2021-05-17  126.820000  128.000000  ...  125.430000  125.430000   386352000
# 519  2021-05-24  126.010002  128.320007  ...  124.610001  124.610001   357615000
# 520  2021-05-31  125.080002  126.160004  ...  125.889999  125.889999   278232500
# 521  2021-06-07  126.169998  128.460007  ...  127.349998  127.349998   326941000
#
# [522 rows x 7 columns]

# %%
# n = len(data)
data['Date'] = pd.to_datetime(data.Date)

# %%
data['Adj Close'].plot()

# %%
X = data[['Open', 'High', 'Low', 'Volume']]
Y = data['Adj Close']

X = X.values
Y = Y.values
# print(X)
# print(Y)

# %%
Xtr,Xts,Ytr,Yts = train_test_split(X,Y)

# %%
lin_model = LinearRegression()
lin_model.fit(Xtr,Ytr)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_pred = lin_model.predict(Xts)
lin_pred
# Out:
# array([ 16.53277606,  33.70229373,  15.5330277 ,  20.22430273,
#         45.19825577,  11.60232612,  15.55291919,  23.14943777,
#         26.02614431,  13.04701509, 135.50315962,  25.0981902 ,
#         42.07471592,  12.05185053, 112.51105923,  51.20807879,
#         13.24505217,  42.91510295,  50.17053264,  42.25093077,
#         26.31469249,  34.09938776,  50.42859069,  23.14377988,
#         14.06498541,  37.17809639,  72.1480469 ,  41.91097765,
#         38.29407877,  15.61661874,  20.62493891,  16.77138144,
#         22.82180905,  36.1687354 ,  43.58573457,  22.2745788 ,
#         11.35110563,  16.22255555,  13.87822385,  76.07058857,
#         52.81940258,  49.54374435,  16.2790192 ,  40.9661962 ,
#         77.88253379,  47.15554459,  20.67753099,  18.06033908,
#         19.43631688,  19.44436467,  55.27272549,  13.54114884,
#         17.98426823,  16.41936647,  37.06939694,  24.82656566,
#         17.13618321,  16.44279876,  42.75103586,  12.7319198 ,
#         15.87899044,  42.98703408,  29.48646823,  46.50674181,
#        132.81929194,  28.0395266 ,  59.92097739, 122.72865464,
#         11.39884575,  18.16323394,  50.84005703,  11.69647441,
#         57.16261011,  19.66976125,  44.09170172,  41.05415903,
#         35.14913918,  78.75673721,  13.23279229,  26.13881957,
#         66.3276645 ,  45.35642763,  19.58177132,  25.42056124,
#         37.90097899,  21.6641889 ,  26.73779157,  79.1809895 ,
#         19.74888565,  48.20514775,  34.32524299,  42.55254676,
#         27.68689997,  22.53598948,  19.46863138,  25.32901488,
#        123.10660107,  24.75107   ,  11.47968851,  18.72650893,
#         63.2724654 ,  23.54006426, 134.38209964,  24.00246479,
#         27.4317442 ,  46.10112728,  41.60526708,  25.51484759,
#         21.5910159 , 118.51085202,  18.64208481,  48.03608526,
#         26.84063002,  18.77275095,  29.51643716,  26.37534144,
#         23.31622265,  48.96244557,  16.41019025,  78.98064591,
#         17.93616809, 137.1539609 , 122.06058215,  86.14668769,
#         91.2543108 ,  15.27415659,  21.75457361,  21.90269975,
#         17.9385731 ,  25.67283238, 103.36348069])

# %%
lin_compare = pd.DataFrame({'Actual':Yts, 'Predicted':lin_pred})
lin_compare
# Out:
#          Actual   Predicted
# 0     16.608511   16.532776
# 1     33.337337   33.702294
# 2     15.385201   15.533028
# 3     18.809093   20.224303
# 4     46.434544   45.198256
# ..          ...         ...
# 126   21.707344   21.754574
# 127   22.495996   21.902700
# 128   17.707096   17.938573
# 129   25.938267   25.672832
# 130  105.548805  103.363481
#
# [131 rows x 2 columns]

# %%
lin_model.score(Xts,Yts)
# Out:
# 0.9992339854596739

# %% [markdown]
# ---
#
#
# ---
#
# **Ridge Model for Apple(AAPL)**
#
# ---

# %%
rid_model = Ridge()
rid_model.fit(Xtr,Ytr)
rid_pred = rid_model.predict(Xts)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=8.07949e-19): result may not be accurate.
#   overwrite_a=True).T

# %%
rid_compare = pd.DataFrame({'Actual':Yts, 'Predicted':rid_pred})
rid_compare
# Out:
#          Actual   Predicted
# 0     16.608511   16.531719
# 1     33.337337   33.702127
# 2     15.385201   15.533572
# 3     18.809093   20.224180
# 4     46.434544   45.201101
# ..          ...         ...
# 126   21.707344   21.755898
# 127   22.495996   21.903851
# 128   17.707096   17.936658
# 129   25.938267   25.674080
# 130  105.548805  103.342377
#
# [131 rows x 2 columns]

# %%
rid_model.score(Xts,Yts)
# Out:
# 0.9992330428607645

# %% [markdown]
# ---
#
#
#
# ---
#
# **Elastic-Net model for Apple(AAPL)**
#
# ---

# %%
els_model = ElasticNet()
els_model.fit(Xtr,Ytr)
els_pred = els_model.predict(Xts)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46.65563851249277, tolerance: 38.201129292357805
#   positive)

# %%
els_compare = pd.DataFrame({'Actual':Yts, 'Predicted':els_pred})
els_compare
# Out:
#          Actual   Predicted
# 0     16.608511   16.328189
# 1     33.337337   33.630565
# 2     15.385201   15.641656
# 3     18.809093   20.181443
# 4     46.434544   45.694262
# ..          ...         ...
# 126   21.707344   22.010668
# 127   22.495996   22.159115
# 128   17.707096   17.581963
# 129   25.938267   25.905942
# 130  105.548805  100.028543
#
# [131 rows x 2 columns]

# %%
els_model.score(Xts,Yts)
# Out:
# 0.9985003193306904

# %% [markdown]
# ---
#
#
#
# ---
#
# **Lasso model for Apple(AAPL)**
#
# ---

# %%
lss_model = Lasso()
lss_model.fit(Xtr,Ytr)
lss_pred = lss_model.predict(Xts)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71.28505074084302, tolerance: 38.201129292357805
#   positive)

# %%
lss_compare = pd.DataFrame({'Actual':Yts, 'Predicted':lss_pred})
lss_compare
# Out:
#          Actual   Predicted
# 0     16.608511   16.306815
# 1     33.337337   33.565177
# 2     15.385201   15.651932
# 3     18.809093   20.152184
# 4     46.434544   45.663993
# ..          ...         ...
# 126   21.707344   22.028331
# 127   22.495996   22.222569
# 128   17.707096   17.566790
# 129   25.938267   25.910352
# 130  105.548805  100.770035
#
# [131 rows x 2 columns]

# %%
lss_model.score(Xts,Yts)
# Out:
# 0.9983042240553556

# %% [markdown]
# ---
#
#
#
# ---
# **Decision Tree Regressor model for Apple(AAPL)**
#
# ---

# %%
ds_model = DecisionTreeRegressor()
ds_model.fit(Xtr,Ytr)
ds_pred = ds_model.predict(Xts)

# %%
ds_compare = pd.DataFrame({'Actual':Yts, 'Predicted':ds_pred})
ds_compare
# Out:
#          Actual   Predicted
# 0     16.608511   16.328323
# 1     33.337337   34.053204
# 2     15.385201   15.491772
# 3     18.809093   20.127623
# 4     46.434544   48.157959
# ..          ...         ...
# 126   21.707344   21.416246
# 127   22.495996   22.146624
# 128   17.707096   17.437908
# 129   25.938267   25.223560
# 130  105.548805  111.729591
#
# [131 rows x 2 columns]

# %%
ds_model.score(Xts,Yts)
# Out:
# 0.9966108870778133
